# %%
import matplotlib.pyplot as plt
import pandas as pd
import pickle
from utils.extract_patients_info import extract_patients_info_to_csv
import torch

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# if not already exported, export patients info to csv file
train_df = extract_patients_info_to_csv()
# otherwise read csv file
#train_df = pd.read_csv('./info/train_patients_info.csv')

# %%
# Count the occurrences of each group for each BMI category
group_counts = train_df.groupby(['bmi_category', 'group']).size().unstack(fill_value=0)

new_index = ['Underweight', 'Healthy', 'Overweight', 'Obesity']
group_counts = group_counts.reindex(new_index)

# Create a bar plot to visualize the counts
ax = group_counts.plot(kind='bar', stacked=False, figsize=(10, 6))

# Add labels and a title
plt.xlabel('BMI Category')
plt.ylabel('Count')
plt.title('Disease Distribution for each BMI Category - Train')

# Show the plot
plt.legend(title='Group')
plt.show()

# %%
# if not already exported, export patients info to csv file
test_df = extract_patients_info_to_csv(train=False)
# otherwise read csv file
#train_df = pd.read_csv('./info/test_patients_info.csv')

# %%
# Count the occurrences of each group for each BMI category
group_counts = test_df.groupby(['bmi_category', 'group']).size().unstack(fill_value=0)

group_counts = group_counts.reindex(new_index)

# Create a bar plot to visualize the counts
ax = group_counts.plot(kind='bar', stacked=False, figsize=(10, 6))

# Add labels and a title
plt.xlabel('BMI Category')
plt.ylabel('Count')
plt.title('Disease Distribution for each BMI Category - Test')

# Show the plot
plt.legend(title='Group')
plt.show()

# %% [markdown]
# # Check Model Performance Per BMI Category

# %% [markdown]
# ## Load Model

# %% [markdown]
# ## Load Test Data For BMI Category

# %% [markdown]
# ## Predict and Evaluate Performance
